# %% [markdown]
# **Фэн Кээцзя иу5и-23м Номер варианта：18**

# %% [markdown]
# Для студентов групп ИУ5-23М, ИУ5И-23М - для произвольной колонки данных построить график "Ящик с усами (boxplot)".

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df=pd.read_csv('china_population.csv')
plt.boxplot(df.Population)
plt.ylabel('Population')
plt.show()

# %% [markdown]
# *Задача №18.*
# Для набора данных проведите масштабирование данных для одного (произвольного) числового признака на основе Z-оценки.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
color=sns.color_palette()
sns.set_style('darkgrid')
pd.set_option('display.float_format',lambda x: '{:.3f}'.format(x))

# %%
dataset=pd.read_csv('china_population.csv')
df=dataset.dropna()
df=df.sort_values(by='Year')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 17 to 0
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          18 non-null     int64
#  1   Population                    18 non-null     int64
#  2   Yearly % Change               18 non-null     float64
#  3   Yearly Change                 18 non-null     int64
#  4   Migrants (net)                18 non-null     int64
#  5   Median Age                    18 non-null     float64
#  6   Fertility Rate                18 non-null     float64
#  7   Density (P/Km²)               18 non-null     int64
#  8   Urban Pop %                   18 non-null     float64
#  9   Urban Population              18 non-null     int64
#  10  Country's Share of World Pop  18 non-null     float64
#  11  World Population              18 non-null     int64
# ...

# %%
sns.scatterplot(x='Density (P/Km²)',y='Fertility Rate',data=df)
# Out:
# <AxesSubplot:xlabel='Density (P/Km²)', ylabel='Fertility Rate'>

# %%
import sklearn.preprocessing
scaler=sklearn.preprocessing.StandardScaler()
df['Fertility Rate']=scaler.fit_transform(df['Fertility Rate'].values.reshape(-1,1))
sns.scatterplot(x='Density (P/Km²)',y='Fertility Rate',data=df)
# Out:
# <AxesSubplot:xlabel='Density (P/Km²)', ylabel='Fertility Rate'>

# %% [markdown]
# *Задача №38.*
# Для набора данных проведите процедуру отбора признаков (feature selection). Используйте класс SelectKBest для 10 лучших признаков, и метод, основанный на взаимной информации.

# %%
ambition = 'Fertility Rate'
df=pd.read_csv('china_population.csv')
X=df.drop(labels=[ambition],axis=1)
y=df[ambition]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression
mi = mutual_info_regression(X,y)
mi = pd.Series(mi)
mi.index = X.columns
mi.sort_values(ascending=False).plot.bar(figsize=(10,5))
plt.ylabel('Взаимная информация')
# Out:
# Text(0, 0.5, 'Взаимная информация')

# %%
selector=SelectKBest(mutual_info_regression,k=10)
selector.fit(X,y)
X_selected=selector.transform(X)
selector.get_support(indices=False)
# Out:
# array([ True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True, False])

# %%
X.columns[selector.get_support()]
# Out:
# Index(['Year', 'Population', 'Yearly % Change', 'Migrants (net)', 'Median Age',
#        'Density (P/Km²)', 'Urban Pop %', 'Urban Population',
#        'Country's Share of World Pop', 'World Population'],
#       dtype='object')

# %%
plt.figure(figsize = (16,5))
sns.heatmap(df.corr(), annot=True, linewidth=1,fmt='.3f')
# Out:
# <AxesSubplot:>
